# %%
#!pip install agentpy

# %%
import agentpy as ap  # Library for creating agents
import numpy as np  # NumPy library for numerical operations
import matplotlib.pyplot as plt  # Library for plotting
from random import randint  # For generating random numbers
import IPython  # For displaying videos in the notebook
from matplotlib.animation import FuncAnimation  # For creating animations (used by agentpy)
import random
import math

# %%
class Message():

    performatives = ["request","inform"]
    parameters = ["content","sender","reply-with","in-reply-to"]

    def __init__(self,msg="",performative="",content="",sender="",query="q1",is_reply=True):
        """Constructor to build a new message"""
        self.empty = False
        self.request = False
        self.inform = False
        self.msg = msg

        #If we want to build a message from the paramters
        if msg == "":
            self.is_reply = is_reply
            self.query = query
            assert performative in Message.performatives , f"Performaive: {performative}"
            self.performative=performative
            self.content = content
            self.sender = sender

        #if we want to build a message from a string (a KQML message)
        else:
            self.decode()

        #Identify if its either Request or Inform performative
        if self.performative == "request":
            self.request = True
        elif self.performative == "inform":
            self.inform = True
        else:
            self.empty = True

    def decode(self):
        """Method to convert a string message (KQML format) to message parameters"""
        current = self.msg[1:-1]
        current = current.split("\n")
        self.performative = current[0]
        assert self.performative in Message.performatives , f"Performaive: {self.performative}"
        parameterList = current[1].split(":")[1:]
        parametersDict = {}
        for parameter in parameterList:
            pair = parameter.split(" ")
            parametersDict[pair[0]] = pair[1]
        if "in-reply-to" in parametersDict.keys():
            self.query = parametersDict["in-reply-to"]
            self.is_reply = True
        else:
            self.query = parametersDict["reply-with"]
            self.is_reply = False
        self.content = parametersDict["content"]
        self.sender = parametersDict["sender"]

    def __str__(self):
        """Method to convert message paramters to a string (KQML format)"""
        s = "("
        s+= self.performative + "\n"
        s+= ":sender " + self.sender
        s+= ":content "+self.content
        if self.is_reply:
            s+= ":in-reply-to " + self.query
        else:
            s+= ":reply-with " + self.query
        s+= ")"
        return s

# %%
class Road(ap.Agent):
    def setup(self):
        self.custom_id = 1 # Custom ID for the road agent
        self.grid_id = 1
        self.overlay_id = np.nan # Overlay ID for the road agent
        self.direction_id = None # Direction ID for the road agent to be set within the model
        # 1= southbound, 2= northbound, 3= eastbound, 4= westbound, 5= intersection area
        self.is_spawn = np.nan # flag to check if the road agent is a spawn point, 10 if spawn point
        self.is_end = np.nan # flag to check if the road agent is an end point, 20 if end point


    def get_position(self):
        return self.model.grid.positions[self]

# %%
class Car(ap.Agent):
    def setup(self):

        self.grid_id = np.nan
        #generate a random 10 digit number to be used as the license plate
        self.license_plate = randint(1000000000, 9999999999)
        self.custom_id = 2 # Custom ID for the car agent
        self.overlay_id = 2
        # Speed of the car all start at 2
        self.speed = 2
        #0 = stopped, 1 = 1 cell pero two time steps, 2 = 1 cell per time step, 3 = 2 cells per time step
        self.sight_distance = 4 # Sight distance of the car
        self.direction = None # Direction of the car
        self.steps_since_last_move = 0 # Steps since the car moved
        #self.has_crossed = False # Flag to check if the car has crossed the intersection
        #self.intersection_time = 0 # Time the car has spent at the intersection
        #self.is_on_intersection = False # Flag to check if the car is on the intersection



    def action(self):
        # Look for the road agent the car is on
        agents = self.model.grid.agents[self.get_position()]
        for agent in agents:
            if agent.custom_id == 1:
                road = agent
                break
        else:
            # If no road agent is found, don't move
            return

        # If the road agent is an end point, remove the car
        if hasattr(road, 'is_end') and road.is_end == 20:

            #before deleting self, clear messages from this agent
            self.clear_old_messages()

            self.model.grid.remove_agents(self)
            self.model.cars.remove(self)
            return
        # Increment the counter for steps since the last move
        self.steps_since_last_move += 1
        
        # Determine if the car moves this step based on its speed
        move_this_step = False
        if self.speed == 1 and self.steps_since_last_move >= 2:
            move_this_step = True
            self.steps_since_last_move = 0  # Reset counter
        elif self.speed == 2 and self.steps_since_last_move >= 1:
            move_this_step = True
            self.steps_since_last_move = 0  # Reset counter
        elif self.speed == 3:
            move_this_step = True  # Always move if speed is 3, and handle double movement

        if move_this_step:
            
            # Update the direction of the car
            self.update_direction(road)

            # Move the car if it can keep moving
            self.see()
            self.move_car()
            # If speed is 3, attempt to move a second time in the same step
            if self.speed == 3:
                self.move_car()

        # Update the speed of the car
        self.update_speed()
        #clear old messages from this agent
        self.clear_old_messages()

        #Brodcast status (speed, direction and position)
        self.broadcast_status()

    def clear_old_messages(self):
        # Access the car's current lane's message board and clear old messages
        current_lane_board = self.model.message_boards[self.direction]
        self.model.message_boards[self.direction] = [msg for msg in current_lane_board if msg.sender != str(self.license_plate)]

    def broadcast_status(self):
        # Create and append a new status message to the current lane's message board
        status_message = Message(
            performative="inform",
            content=f"Speed: {self.speed}, Position: {self.get_position()}",
            sender=str(self.license_plate),
            query="statusUpdate",
            is_reply=False
        )
        self.model.message_boards[self.direction].append(status_message)
        # print the message for debugging
        print(f"Broadcasting status: {status_message}")


    def update_direction(self, road):
        #check if agent has crossed the entire intersection
        #if self.intersection_time == self.model.intersection_length:
        #    self.has_crossed = True
        #    self.intersection_time = 0
        #get the direction of the road agent
        road_direction = road.direction_id
        #move the car based on the direction of the road agent. if intersection, move based on the direction already set
        if road_direction != 5:
            self.direction = road_direction
        #else:
         #   self.direction = self.direction
          #  self.is_on_intersection = True
           # self.intersection_time += 1
            


    def move_car(self):
        # check if speed is 0, if so, do not move
        if self.speed == 0:
            return

        # Move the car based on the direction
        if self.direction == 1:
            self.model.grid.move_by(self, (1, 0))
        elif self.direction == 2:
            self.model.grid.move_by(self, (-1, 0))
        elif self.direction == 3:
            self.model.grid.move_by(self, (0, 1))
        elif self.direction == 4:
            self.model.grid.move_by(self, (0, -1))

    def see(self):
        for distance in range(1, self.sight_distance + 1):
            # Check for a car at the current distance
            if self.search_for_car(distance):
                return  # Stop further checks if action required for a car
            # Check for a traffic light at the current distance
            if self.search_for_traffic_light(distance):
                return  # Stop further checks if action required for a traffic light
            
        # See if car from any direction has run a red light and is 1 to 2 cells in front of the car (to slam on the brakes)
        for distance in range(1, 2):
            if self.check_red_light_runners(distance):
                return
            


        # If checks up to 4 tiles ahead don't require stopping or slowing, then check for space after the intersection
        #self.check_space_after_intersection()
    def check_red_light_runners(self, distance):
        anticipated_position = self.get_position_ahead(distance)
        print(f"[Debug - Red Light Runner Check] Agent {self.license_plate} position: {self.get_position()}, Direction: {self.direction}")
        print(f"[Debug - Red Light Runner Check] Anticipated position for distance {distance}: {anticipated_position}")

        if not anticipated_position:
            print("[Debug - Red Light Runner Check] No anticipated position. Returning False.")
            return False

        # Iterate through all message boards except the one corresponding to the car's current direction
        for direction, message_board in self.model.message_boards.items():
            if direction == self.direction:
                continue  # Skip the car's own lane

            for message in message_board:
                content = message.content
                try:
                    speed_part, position_part = content.rsplit(', Position:', 1)
                    # Assuming speed is not needed for red light runner check, but kept here for completeness
                    speed = int(speed_part.split(': ')[1])
                    position = eval(f"({position_part})")  # Safely convert position string to tuple
                except ValueError as e:
                    print(f"[Debug - Red Light Runner Check] Error parsing message content: {e}")
                    continue  # Skip this message if there's an error

                print(f"[Debug - Red Light Runner Check] Reading message from sender {message.sender}: Position {position}")
                
                if position == anticipated_position:
                    # Found a message indicating a car at the anticipated position from a different direction
                    print(f"[Action - Red Light Runner Check] Agent {self.license_plate} detected a red light runner at {position}. Stopping.")
                    self.speed = 0
                    return True

        print("[Debug - Red Light Runner Check] No red light runners detected.")
        return False

        

    def search_for_car(self, distance):
        anticipated_position = self.get_position_ahead(distance)
        print(f"Agent position: {self.get_position()}")
        print(f"Anticipated position: {anticipated_position}")

        if not anticipated_position:
            return False

        for message in self.model.message_boards[self.direction]:
            content = message.content
            try:
                # Use rsplit to split only on the first comma, which separates speed from position
                speed_part, position_part = content.rsplit(', Position:', 1)
                speed = int(speed_part.split(': ')[1])
                position = eval(f"({position_part})")  # Encapsulate in parentheses to ensure it's a tuple
            except ValueError as e:
                print(f"Error parsing message content: {e}")
                continue

            if position == anticipated_position:
                if distance == 1:
                    self.speed = 0
                    return True
                elif distance in [2, 3, 4]:
                    if speed < self.speed:
                        self.speed = max(speed, 1 if distance == 2 else 2)
                    return True

        return False



       


    """ def search_for_car(self, distance):
        # Look ahead a certain distance in front of the car
        # If car is right in front, stop (speed 0)
        # If car is 2 cells ahead, reduce speed to match (if slower) (min speed 1 to avoid stopping)
        # If car is 3-4 cells ahead, reduce speed to match (if slower) (min speed 2 to avoid stopping)
        # at every comparison check if car is moving in the same direction

        agents = self.look_ahead(distance)  # Look ahead a certain distance
        for agent in agents:
            # Check if the agent is a car
            if agent.custom_id == 2 and agent.direction == self.direction:
                # If the car is right in front, stop the car
                if distance == 1:
                    self.speed = 0
                    return True
                # If the car is 2 cells ahead, reduce speed to match (if slower)
                elif distance == 2:
                    # If the car in front is slower, reduce speed to match (min speed 1)
                    if agent.speed < self.speed:
                        self.speed = max(agent.speed, 1)
                    return True
                # If the car is 3-4 cells ahead, reduce speed to match (if slower)
                elif distance in [3, 4]:
                    # If the car in front is slower, reduce speed to match (min speed 2)
                    if agent.speed < self.speed:
                        self.speed = max(agent.speed, 2)
                    return True
        return False """
    
    def get_position_ahead(self, distance):
        # Get the car's current position
        current_position = self.get_position()
        next_position = None
        

        # Calculate the next position based on the car's current direction and the distance
        if self.direction == 1:  # South
            next_position = (current_position[0] + distance, current_position[1])
        elif self.direction == 2:  # North
            next_position = (current_position[0] - distance, current_position[1])
        elif self.direction == 3:  # East
            next_position = (current_position[0], current_position[1] + distance)
        elif self.direction == 4:  # West
            next_position = (current_position[0], current_position[1] - distance)

        # Check if the next position is within the grid boundaries. if notreturn empyt list
        if next_position and 0 <= next_position[0] < self.model.p.dimensions and 0 <= next_position[1] < self.model.p.dimensions:
            return next_position
        else:
            return []
        

    def search_for_traffic_light(self, distance):
        # Look ahead a certain distance in front of the car
        #if light is right in front, stop
        #if light is 2-4 cells ahead, reduce speed to 2 (1 cell per time step)
        agents = self.look_ahead(distance) # Look ahead a certain distance
        for agent in agents:
            # Check if the agent is a traffic light
            if agent.custom_id == 3:
                # If the traffic light is red or yellow (and takes into account chance to run yellow light and red lights) stop the car
                if (agent.state == 100 and random.random() > self.model.p.chance_run_red_light) or (agent.state == 102 and random.random() > self.model.p.chance_run_yellow_light):
                    #check distance to light for speed reduction
                    # if distance is 1, stop
                    if distance == 1:
                        self.speed = 0
                        return True
                    else:
                        # if distance is 2-4, reduce speed to 2
                        self.speed = 2
                        return True
        return False
    

                
            

    def look_ahead(self, distance):

        # Get the car's current position
        current_position = self.get_position()
        next_position = None

        # Calculate the next position based on the car's current direction and the distance
        if self.direction == 1:  # South
            next_position = (current_position[0] + distance, current_position[1])
        elif self.direction == 2:  # North
            next_position = (current_position[0] - distance, current_position[1])
        elif self.direction == 3:  # East
            next_position = (current_position[0], current_position[1] + distance)
        elif self.direction == 4:  # West
            next_position = (current_position[0], current_position[1] - distance)

        # Check if the next position is within the grid boundaries
        if next_position and 0 <= next_position[0] < self.model.p.dimensions and 0 <= next_position[1] < self.model.p.dimensions:
            return self.model.grid.agents[next_position]
        else:
            return []  # Return an empty list if the position is outside the grid boundaries
    
    def update_speed(self):
        # Increase speed by 1 every 2 steps, up to a maximum of 3
        if self.model.t % 2 == 0:  # Assuming there's a model-wide timer you can access
            self.speed = min(self.speed + 1, 3)


        
    def get_position(self):
        return self.model.grid.positions[self]

# %%
class Traffic_Light(ap.Agent):
    def setup(self):
        self.custom_id = 3 # Custom ID for the traffic light agent
        self.grid_id = 1
        self.overlay_id = 3
        self.state = 100 # State of the traffic light, 100 = red, 101 = green


        
    def get_position(self):
        return self.model.grid.positions[self]

# %%
class TrafficController(ap.Agent):
    def setup(self):
        self.custom_id = 4  # Custom ID
        self.grid_id = np.nan
        self.overlay_id = np.nan
        self.traffic_lights = [[], [], [], []]  # Traffic lights per direction
        self.timer = 0
        # Current active traffic light direction
        self.current_active = None 
        # Initialize state to track the phase (Green, Yellow, Red)
        self.phase = "Green"
        # Define the order of traffic light activation for counter-clockwise rotation
        self.activation_order = [3, 2, 4, 1]  # East, North, West, South (counter-clockwise)

    def switch_traffic_lights(self):
        # If there's no currently active direction, initialize it
        if self.current_active is None:
            self.current_active = self.activation_order[0]
            self.set_traffic_lights(self.current_active, 101)  # Start with green
        else:
            if self.phase == "Green":
                # After green, switch current lights to yellow
                self.set_traffic_lights(self.current_active, 102)  # Yellow
                self.phase = "Yellow"
                self.timer = 0  # Reset timer for yellow phase duration
            elif self.phase == "Yellow" and self.timer >= 5:
                # After yellow duration, switch current to red and next to green
                self.set_traffic_lights(self.current_active, 100)  # Current to Red
                # Determine the next direction
                current_index = self.activation_order.index(self.current_active)
                next_index = (current_index + 1) % len(self.activation_order)
                self.current_active = self.activation_order[next_index]
                self.set_traffic_lights(self.current_active, 101)  # Next to Green
                self.phase = "Green"
                self.timer = 0  # Reset timer for green phase duration

    def set_traffic_lights(self, direction, state):
        """Set the state of traffic lights in a specific direction."""
        for light in self.traffic_lights[direction - 1]:  # Adjust index for 0-based
            light.state = state

    def action(self):
        self.timer += 1  # Increment the global timer
        # Every 15 steps, or if in yellow phase and 5 steps have passed, switch traffic lights
        if self.timer % 15 == 0 or (self.phase == "Yellow" and self.timer >= 5):
            self.switch_traffic_lights()

# %%
class IntersectionModel(ap.Model):
    def setup(self):
        self.spawn_points = [] # List to store the spawn points
        # Create grid
        self.grid = ap.Grid(self, (self.p.dimensions, self.p.dimensions))


        self.pre_intersection_pos = []  # List to store pre-intersection positions
        # Create roads
        self.setup_roads()
        # Setup traffic lights
        self.setup_traffic_lights()


        print("traffic light position: ", self.pre_intersection_pos)

        # Create cars
        self.cars = [] # List to store the car agents




        #since attr grid isnt working, create a grid to store the positions of the cars
        self.pos_grid = np.full((self.p.dimensions, self.p.dimensions), np.nan)

        # same for the traffic lights
        self.traffic_light_grid = np.full((self.p.dimensions, self.p.dimensions), np.nan)

         # Initialize a message board for each lane direction
        self.message_boards = {
            1: [],  # Southbound
            2: [],  # Northbound
            3: [],  # Eastbound
            4: []   # Westbound
        }



                    
    def step(self):
       
        self.update_car_count()
        for car in self.cars:
            car.action()

        self.traffic_controller.action()


    def update(self):
        self.update_pos_grid()
        self.update_traffic_light_grid()
        pass

    def end(self):
        #print each of the messages by message board and its contents
        for key in self.message_boards:
            print(f"Message board {key}:")
            for message in self.message_boards[key]:
                print(message)
            print()
        pass


    def setup_traffic_lights(self):
        # Create traffic controller
        self.traffic_controller = ap.AgentList(self, 1, TrafficController)[0]  # Note the [0] to get the actual agent

        # Create traffic lights
        self.traffic_lights = ap.AgentList(self, len(self.pre_intersection_pos), Traffic_Light)
        self.grid.add_agents(self.traffic_lights, self.pre_intersection_pos)

        # Add the traffic lights to the traffic controller
        for light, pos in zip(self.traffic_lights, self.pre_intersection_pos):
            # Determine the direction based on the intersection matrix and explicitly cast to int
            direction = int(self.intersection_matrix[pos[0]][pos[1]])
            
            # Assign the light to the correct list based on direction
            # Assuming 1= southbound, 2= northbound, 3= eastbound, 4= westbound
            if direction in [1, 2, 3, 4]:
                # Subtract 1 to match direction to index (0-3) in the traffic_lights list
                self.traffic_controller.traffic_lights[direction - 1].append(light)



    def update_pos_grid(self):
        #clear grid with nan
        self.pos_grid = np.full((self.p.dimensions, self.p.dimensions), np.nan)

        #update grid with car positions
        for car in self.cars:
            pos = car.get_position()
            self.pos_grid[pos] = car.custom_id

    def update_traffic_light_grid(self):
        # Clear grid with NaN
        self.traffic_light_grid = np.full((self.p.dimensions, self.p.dimensions), np.nan)

        # Update grid with traffic light states
        for light in self.traffic_lights:
            pos = light.get_position()
            self.traffic_light_grid[pos] = light.state


    def update_car_count(self): #Function to add cars to the grid
        # Adds cars to the grid until the max is reached or spawn points are full
        
        if np.random.rand() < self.p.spawn_rate:
        # Check if the number of cars has reached the maximum
            if len(self.cars) == self.p.max_cars:
                print("Max cars reached")
                return # Return if the maximum number of cars has been reached
            
            # Check spawn points arent full
            uncovered_spawn_points = []
            for spawn_point in self.spawn_points:

                # Check if the spawn point is covered by a car

                if len(self.grid.agents[spawn_point.get_position()[0]]) == 1:
                    uncovered_spawn_points.append(spawn_point) # Add to the list of uncovered spawn points
            
            if len(uncovered_spawn_points) == 0:
                #print("All spawn points covered")
                return # Return if all spawn points are covered
        
            self.add_car(uncovered_spawn_points) # Add a car to the grid



    def add_car(self, spawn_points): #Function to add cars to the grid

        #Print available spawn points coordinates
        #print("Available spawn points: ", [spawn_point.get_position() for spawn_point in spawn_points])

        # Add a car to the grid
        car = ap.AgentList(self, 1, Car)
        
        # Randomly select a spawn point, if it is covered, try again
        spawn_point = spawn_points[randint(0, len(spawn_points) - 1)]
        #print("adding car at ", spawn_point.get_position())

        # Add the car to the grid
        self.grid.add_agents(car, spawn_point.get_position())
        #print("Car added at ", car.get_position())
        self.cars.append(car[0]) # Add the car to the list of cars

        

    def setup_roads(self):
        intersection_agents = []  # List to store the intersection agents
        # CREATE ROAD AGENTS
        # Create the intersection matrix
        self.intersection_matrix = self.create_intersection_matrix(self.p.dimensions, self.p.dimensions)
        #print(self.intersection_matrix)
    
        # Add road agents to the grid following the intersection matrix, adding each road agent to their respective direction
        # 1= southbound, 2= northbound, 3= eastbound, 4= westbound, 5= intersection area
        for i in range(self.p.dimensions):
            for j in range(self.p.dimensions):
                if self.intersection_matrix[i][j] != 0:
                    #print(i, j, int(self.intersection_matrix[i][j]))
                    road = ap.AgentList(self, 1, Road)
                    road[0].direction_id = int(self.intersection_matrix[i][j])
                    self.grid.add_agents(road, [(int(i), int(j))])
                    #if the agent is intersection add to itnersection list
                    if int(self.intersection_matrix[i][j]) == 5:
                        intersection_agents.append(road[0])
        #get length of intersection by getting the square root of the length of the intersection agents
        self.intersection_length = int(math.sqrt(len(intersection_agents)))
                    


        # MARK SPAWN AND END POINTS
        self.mark_spawn_and_end_points()
        self.mark_pre_intersection_points()

    def mark_pre_intersection_points(self):
        # Iterate over the intersection matrix to find lanes leading to the intersection
        for i in range(self.p.dimensions):
            for j in range(self.p.dimensions):
                if self.intersection_matrix[i][j] in [1, 2, 3, 4]:  # Road directions
                    if self.is_pre_intersection(i, j, self.intersection_matrix[i][j]):
                        # Directly store the position of this pre-intersection point
                        self.pre_intersection_pos.append((i, j))



    def is_pre_intersection(self, x, y, direction):
        """
        Check if the given position is directly before an intersection
        based on the road's direction, ensuring not to go outside the matrix bounds.
        """
        dimensions = self.p.dimensions  # Assuming this is the size of your grid/matrix

        if direction == 1:  # Southbound, check below if not at bottom edge
            return x < dimensions - 1 and self.intersection_matrix[x+1][y] == 5
        elif direction == 2:  # Northbound, check above if not at top edge
            return x > 0 and self.intersection_matrix[x-1][y] == 5
        elif direction == 3:  # Eastbound, check right if not at rightmost edge
            return y < dimensions - 1 and self.intersection_matrix[x][y+1] == 5
        elif direction == 4:  # Westbound, check left if not at leftmost edge
            return y > 0 and self.intersection_matrix[x][y-1] == 5
        return False



    def create_intersection_matrix(self, n, m):
        # Initialize the matrix with zeros
        matrix = np.zeros((n, m))
        
        # Determine the central points
        center_n = n // 2 # center of rows/height
        center_m = m // 2 # center of columns/width
        
        # Adjust for even dimensions - to ensure the intersection is centered
        n_start = center_n - 1 if n % 2 == 0 else center_n
        m_start = center_m - 1 if m % 2 == 0 else center_m
        
        # Create intersection area
        for i in range(n_start, n_start+2):
            for j in range(m_start, m_start+2):
                matrix[i][j] = 5
        
        # Create lanes leading to the intersection
        # Southbound and Northbound lanes
        for i in range(n_start):
            matrix[i][m_start] = 1
            matrix[i][m_start+1] = 2
        for i in range(n_start+2, n):
            matrix[i][m_start] = 1
            matrix[i][m_start+1] = 2
        
        # Eastbound and Westbound lanes
        for j in range(m_start):
            matrix[n_start][j] = 4
            matrix[n_start+1][j] = 3
        for j in range(m_start+2, m):
            matrix[n_start][j] = 4
            matrix[n_start+1][j] = 3
        
        # 1= southbound, 2= northbound, 3= eastbound, 4= westbound, 5= intersection area
        return matrix
        
    def mark_spawn_and_end_points(self):
        dimensions = self.p.dimensions
        for i in range(dimensions):
            for j in range(dimensions):
                direction_id = int(self.intersection_matrix[i][j])
                if direction_id != 0:
                    road_agents = self.grid.agents[(i, j)]
                    if not road_agents:
                        continue  # No agent at this position, should not happen but check for safety
                    
                    road_agent = road_agents  # Assuming one agent per grid cell
                    # Check if the agent's position is at the edge and matches the direction for a spawn point
                    if (direction_id == 1 and i == 0) or (direction_id == 2 and i == dimensions - 1) or \
                    (direction_id == 3 and j == 0) or (direction_id == 4 and j == dimensions - 1):
                        road_agent.is_spawn = 10
                        self.spawn_points.append(road_agent)
                        
                    # Check if the agent's position is at the opposite edge and matches the direction for an end point
                    if (direction_id == 1 and i == dimensions - 1) or (direction_id == 2 and i == 0) or \
                    (direction_id == 3 and j == dimensions - 1) or (direction_id == 4 and j == 0):
                        road_agent.is_end = 20

# %%
parameters={
    'dimensions': 8,  # Dimensions of the grid, minimum 4
    'steps': 150,  # Number of steps to run the model
    'max_cars': 3, # Maximum number of cars
    'spawn_rate': 1, # Rate of car spawn, chance of car spawn per step 
    'chance_run_yellow_light': 0.5, # Chance of running a yellow light
    'chance_run_red_light': 0.5, # Chance of running a red light
}

model = IntersectionModel(parameters)
results = model.run()

#print(model.intersection_agent)
# Out:
# traffic light position:  [(2, 3), (3, 5), (4, 2), (5, 4)]
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Agent position: (0, 3)
# Anticipated position: (4, 3)
# [Debug - Red Light Runner Check] Agent 2032804747 position: (0, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2032804747:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Completed: 1 stepsAgent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 2032804747 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2032804747:content Speed: 3, Position: (2, 3):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 3, Position: (6, 4):reply-with statusUpdate)
# Completed: 2 stepsAgent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 2032804747 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2032804747:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Agent position: (0, 3)
# Anticipated position: (4, 3)
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Completed: 3 stepsMax cars reached
# Agent position: (4, 3)
# Anticipated position: (5, 3)
# Agent position: (4, 3)
# Anticipated position: (6, 3)
# Agent position: (4, 3)
# Anticipated position: (7, 3)
# Agent position: (4, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2032804747 position: (4, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2032804747:content Speed: 3, Position: (6, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 4 stepsMax cars reached
# Agent position: (6, 3)
# Anticipated position: (7, 3)
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2032804747 position: (6, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2032804747:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Agent position: (6, 4)
# Anticipated position: (3, 4)
# Agent position: (6, 4)
# Anticipated position: (2, 4)
# [Debug - Red Light Runner Check] Agent 2408571946 position: (6, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2032804747: Position (7, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 1, Position: (5, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 5 stepsMax cars reached
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 6 stepsBroadcasting status: (inform
# :sender 2408571946:content Speed: 1, Position: (5, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 0, Position: (0, 3):reply-with statusUpdate)
# Completed: 7 stepsMax cars reached
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Agent position: (5, 4)
# Anticipated position: (2, 4)
# Agent position: (5, 4)
# Anticipated position: (1, 4)
# [Debug - Red Light Runner Check] Agent 2408571946 position: (5, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (0, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 2, Position: (4, 4):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 3347993397 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 1, Position: (0, 3):reply-with statusUpdate)
# Completed: 8 stepsMax cars reached
# Agent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Agent position: (4, 4)
# Anticipated position: (0, 4)
# [Debug - Red Light Runner Check] Agent 2408571946 position: (4, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (0, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 3347993397 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 2, Position: (3, 3):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 9 stepsMax cars reached
# Agent position: (3, 4)
# Anticipated position: (2, 4)
# Agent position: (3, 4)
# Anticipated position: (1, 4)
# Agent position: (3, 4)
# Anticipated position: (0, 4)
# Agent position: (3, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2408571946 position: (3, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 3, Position: (2, 4):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (4, 3)
# Agent position: (3, 3)
# Anticipated position: (5, 3)
# Agent position: (3, 3)
# Anticipated position: (6, 3)
# Agent position: (3, 3)
# Anticipated position: (7, 3)
# [Debug - Red Light Runner Check] Agent 3347993397 position: (3, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (2, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Completed: 10 stepsMax cars reached
# Agent position: (2, 4)
# Anticipated position: (1, 4)
# Agent position: (2, 4)
# Anticipated position: (0, 4)
# Agent position: (2, 4)
# Anticipated position: []
# Agent position: (2, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2408571946 position: (2, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2408571946:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (5, 3)
# Agent position: (4, 3)
# Anticipated position: (6, 3)
# Agent position: (4, 3)
# Anticipated position: (7, 3)
# Agent position: (4, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3347993397 position: (4, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 3, Position: (6, 3):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 4778053153 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2408571946: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
# Completed: 11 stepsMax cars reached
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Completed: 12 stepsAgent position: (6, 3)
# Anticipated position: (7, 3)
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3347993397 position: (6, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (7, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3347993397:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (4, 3)
# Agent position: (3, 3)
# Anticipated position: (5, 3)
# Agent position: (3, 3)
# Anticipated position: (6, 3)
# Agent position: (3, 3)
# Anticipated position: (7, 3)
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 3, Position: (5, 3):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Agent position: (7, 4)
# Anticipated position: (4, 4)
# Agent position: (7, 4)
# Anticipated position: (3, 4)
# [Debug - Red Light Runner Check] Agent 9349114885 position: (7, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (6, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3347993397: Position (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (5, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 2, Position: (6, 4):reply-with statusUpdate)
# Completed: 13 stepsMax cars reached
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Completed: 14 stepsAgent position: (5, 3)
# Anticipated position: (6, 3)
# Agent position: (5, 3)
# Anticipated position: (7, 3)
# Agent position: (5, 3)
# Anticipated position: []
# Agent position: (5, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 4778053153 position: (5, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (6, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 4778053153:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# [Debug - Red Light Runner Check] Agent 5076825095 position: (3, 7), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 6)
# [Debug - Red Light Runner Check] Reading message from sender 4778053153: Position (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5076825095:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Completed: 15 stepsMax cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 5076825095 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5076825095:content Speed: 3, Position: (3, 5):reply-with statusUpdate)
# Completed: 16 stepsAgent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 5076825095 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5076825095:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Completed: 17 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5076825095 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5076825095:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Completed: 18 stepsMax cars reached
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5076825095 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5076825095:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Completed: 19 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Completed: 20 stepsAgent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Agent position: (6, 4)
# Anticipated position: (3, 4)
# Agent position: (6, 4)
# Anticipated position: (2, 4)
# [Debug - Red Light Runner Check] Agent 9349114885 position: (6, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2019165529: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (5, 4):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 2019165529 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (5, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 1, Position: (3, 5):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Completed: 21 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 2, Position: (5, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Completed: 22 stepsMax cars reached
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Agent position: (5, 4)
# Anticipated position: (2, 4)
# Agent position: (5, 4)
# Anticipated position: (1, 4)
# [Debug - Red Light Runner Check] Agent 9349114885 position: (5, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2019165529: Position (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 2641655344: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 2, Position: (4, 4):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 2019165529 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Completed: 23 stepsMax cars reached
# Agent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Agent position: (4, 4)
# Anticipated position: (0, 4)
# [Debug - Red Light Runner Check] Agent 9349114885 position: (4, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2019165529: Position (3, 4)
# [Action - Red Light Runner Check] Agent 9349114885 detected a red light runner at (3, 4). Stopping.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (4, 4):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Agent position: (3, 4)
# Anticipated position: (3, 0)
# [Debug - Red Light Runner Check] Agent 2019165529 position: (3, 4), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 3, Position: (3, 4):reply-with statusUpdate)
# Completed: 24 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 1, Position: (4, 4):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2019165529 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 3, Position: (3, 2):reply-with statusUpdate)
# Completed: 25 stepsMax cars reached
# Agent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Agent position: (4, 4)
# Anticipated position: (0, 4)
# [Debug - Red Light Runner Check] Agent 9349114885 position: (4, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2019165529: Position (3, 1)
# [Debug - Red Light Runner Check] Reading message from sender 2641655344: Position (3, 2)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2019165529 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2019165529:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (3, 2)
# Anticipated position: (3, 1)
# Agent position: (3, 2)
# Anticipated position: (3, 0)
# Broadcasting status: (inform
# :sender 2641655344:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Completed: 26 stepsMax cars reached
# Agent position: (3, 4)
# Anticipated position: (2, 4)
# Agent position: (3, 4)
# Anticipated position: (1, 4)
# Agent position: (3, 4)
# Anticipated position: (0, 4)
# Agent position: (3, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9349114885 position: (3, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2019165529: Position (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 2641655344: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 2, Position: (2, 4):reply-with statusUpdate)
# Completed: 27 stepsAgent position: (2, 4)
# Anticipated position: (1, 4)
# Agent position: (2, 4)
# Anticipated position: (0, 4)
# Agent position: (2, 4)
# Anticipated position: []
# Agent position: (2, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9349114885 position: (2, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2641655344: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 3, Position: (1, 4):reply-with statusUpdate)
# Completed: 28 stepsAgent position: (1, 4)
# Anticipated position: (0, 4)
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9349114885 position: (1, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9349114885:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 9349114885: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Completed: 29 stepsMax cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Completed: 30 stepsAgent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 0, Position: (4, 1):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 0, Position: (4, 0):reply-with statusUpdate)
# Completed: 31 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 1, Position: (4, 0):reply-with statusUpdate)
# Completed: 32 stepsMax cars reached
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 1, Position: (4, 2):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Completed: 33 stepsMax cars reached
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 2, Position: (4, 2):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Completed: 34 stepsMax cars reached
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 2, Position: (4, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 0, Position: (4, 1):reply-with statusUpdate)
# Completed: 35 stepsMax cars reached
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 3626779280 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 9662377158: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Completed: 36 stepsMax cars reached
# Agent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 3626779280 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 9662377158: Position (4, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 6988646234 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 1, Position: (4, 2):reply-with statusUpdate)
# Completed: 37 stepsMax cars reached
# Agent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9662377158 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9662377158:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Agent position: (3, 4)
# Anticipated position: (3, 0)
# [Debug - Red Light Runner Check] Agent 3626779280 position: (3, 4), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 9662377158: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 2, Position: (4, 2):reply-with statusUpdate)
# Completed: 38 stepsMax cars reached
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 6988646234 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 2, Position: (4, 3):reply-with statusUpdate)
# Completed: 39 stepsAgent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3626779280 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 6988646234 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Agent position: (0, 3)
# Anticipated position: (4, 3)
# [Debug - Red Light Runner Check] Agent 3386429231 position: (0, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 3, Position: (1, 3):reply-with statusUpdate)
# Completed: 40 stepsMax cars reached
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3626779280 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 3386429231: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3626779280:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 6988646234 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 3386429231: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3626779280: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 0, Position: (1, 3):reply-with statusUpdate)
# Completed: 41 stepsMax cars reached
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 42 stepsAgent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 6988646234 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 3386429231: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6988646234:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 3386429231 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 6988646234: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 1, Position: (2, 3):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 43 stepsMax cars reached
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Completed: 44 stepsBroadcasting status: (inform
# :sender 3386429231:content Speed: 1, Position: (2, 3):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 0, Position: (1, 3):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 7184388846 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 3386429231: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 5914335312: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 7184388846:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Completed: 45 stepsMax cars reached
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 3386429231 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 7184388846: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 2, Position: (3, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 7184388846:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Completed: 46 stepsMax cars reached
# Agent position: (3, 3)
# Anticipated position: (4, 3)
# Agent position: (3, 3)
# Anticipated position: (5, 3)
# Agent position: (3, 3)
# Anticipated position: (6, 3)
# Agent position: (3, 3)
# Anticipated position: (7, 3)
# [Debug - Red Light Runner Check] Agent 3386429231 position: (3, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 7184388846: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 2, Position: (4, 3):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 0, Position: (1, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 7184388846:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Completed: 47 stepsMax cars reached
# Agent position: (4, 3)
# Anticipated position: (5, 3)
# Agent position: (4, 3)
# Anticipated position: (6, 3)
# Agent position: (4, 3)
# Anticipated position: (7, 3)
# Agent position: (4, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3386429231 position: (4, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 7184388846: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3386429231:content Speed: 3, Position: (5, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 5914335312:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# ...
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3959389666:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 8681090299 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3959389666: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8681090299:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Completed: 138 stepsMax cars reached
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 8613388258 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 8681090299: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 1, Position: (2, 3):reply-with statusUpdate)
# Completed: 139 stepsAgent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8681090299 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (2, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8681090299:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 3, Position: (6, 4):reply-with statusUpdate)
# Completed: 140 stepsMax cars reached
# Agent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8681090299 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8681090299:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 8613388258 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (6, 4)
# [Debug - Red Light Runner Check] Reading message from sender 8681090299: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 2, Position: (3, 3):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Completed: 141 stepsMax cars reached
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Completed: 142 stepsAgent position: (3, 3)
# Anticipated position: (4, 3)
# Agent position: (3, 3)
# Anticipated position: (5, 3)
# Agent position: (3, 3)
# Anticipated position: (6, 3)
# Agent position: (3, 3)
# Anticipated position: (7, 3)
# [Debug - Red Light Runner Check] Agent 8613388258 position: (3, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 2, Position: (4, 3):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Agent position: (6, 4)
# Anticipated position: (3, 4)
# Agent position: (6, 4)
# Anticipated position: (2, 4)
# [Debug - Red Light Runner Check] Agent 2381016952 position: (6, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 1, Position: (5, 4):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 1067640267 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (5, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1067640267:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Completed: 143 stepsMax cars reached
# Agent position: (4, 3)
# Anticipated position: (5, 3)
# Agent position: (4, 3)
# Anticipated position: (6, 3)
# Agent position: (4, 3)
# Anticipated position: (7, 3)
# Agent position: (4, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8613388258 position: (4, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1067640267: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 3, Position: (5, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 2, Position: (5, 4):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 1067640267 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (5, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1067640267:content Speed: 3, Position: (4, 2):reply-with statusUpdate)
# Completed: 144 stepsMax cars reached
# Agent position: (5, 3)
# Anticipated position: (6, 3)
# Agent position: (5, 3)
# Anticipated position: (7, 3)
# Agent position: (5, 3)
# Anticipated position: []
# Agent position: (5, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8613388258 position: (5, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (6, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1067640267: Position (4, 2)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8613388258:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Agent position: (5, 4)
# Anticipated position: (2, 4)
# Agent position: (5, 4)
# Anticipated position: (1, 4)
# [Debug - Red Light Runner Check] Agent 2381016952 position: (5, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 1067640267: Position (4, 2)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 2, Position: (4, 4):reply-with statusUpdate)
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 1067640267 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 8613388258: Position (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1067640267:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Completed: 145 stepsMax cars reached
# Agent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 1067640267 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1067640267:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Completed: 146 stepsAgent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Agent position: (4, 4)
# Anticipated position: (0, 4)
# [Debug - Red Light Runner Check] Agent 2381016952 position: (4, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1067640267: Position (4, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 1067640267 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1067640267:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 6473916810:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Completed: 147 stepsMax cars reached
# Agent position: (3, 4)
# Anticipated position: (2, 4)
# Agent position: (3, 4)
# Anticipated position: (1, 4)
# Agent position: (3, 4)
# Anticipated position: (0, 4)
# Agent position: (3, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2381016952 position: (3, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6473916810: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 1067640267: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 3, Position: (2, 4):reply-with statusUpdate)
# Completed: 148 stepsAgent position: (2, 4)
# Anticipated position: (1, 4)
# Agent position: (2, 4)
# Anticipated position: (0, 4)
# Agent position: (2, 4)
# Anticipated position: []
# Agent position: (2, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2381016952 position: (2, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6473916810: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2381016952:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 6473916810 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 6473916810:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 3037544863 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 6473916810: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2381016952: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3037544863:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Completed: 149 stepsMax cars reached
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 3037544863 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 6473916810: Position (2, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3037544863:content Speed: 3, Position: (4, 2):reply-with statusUpdate)
# Completed: 150 stepsMessage board 1:
# (inform
# :sender 6473916810:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
#
# Message board 2:
#
# Message board 3:
# (inform
# :sender 3037544863:content Speed: 3, Position: (4, 2):reply-with statusUpdate)
#
# Message board 4:
#
#
# Run time: 0:00:00.041320
# Simulation finished

# %%
def animation_plot(model, ax):
    # get all road agents


    attr_grid = model.grid.attr_grid('grid_id')


    #get pos_grid
    pos_grid = model.pos_grid
    pos_mask = ~np.isnan(pos_grid)

    attr_grid[pos_mask] = pos_grid[pos_mask]

    #get traffic light grid
    traffic_light_grid = model.traffic_light_grid
    traffic_light_mask = ~np.isnan(traffic_light_grid)

    attr_grid[traffic_light_mask] = traffic_light_grid[traffic_light_mask]
    
    
    color_dict = {1: 'gray', 2: 'orange',100: 'red', 101: 'green',  102: 'yellow', 5: 'black', None: 'white'}

    ap.gridplot(attr_grid, ax=ax, color_dict=color_dict, convert=True)

    ax.set_title(f"Road Generation Model\n"
                 f"step: {model.t}\n"
                f"cars: {len(model.cars)}")

fig, ax = plt.subplots()
model2 = IntersectionModel(parameters)
animation = ap.animate(model2, fig, ax, animation_plot)

IPython.display.HTML(animation.to_jshtml(fps=10))
# Out:
# traffic light position:  [(2, 3), (3, 5), (4, 2), (5, 4)]
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 2597904184 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2597904184:content Speed: 3, Position: (4, 1):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 2597904184 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2597904184:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Agent position: (0, 3)
# Anticipated position: (4, 3)
# [Debug - Red Light Runner Check] Agent 2090491037 position: (0, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2597904184: Position (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 2818276599 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2597904184: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 2597904184 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2597904184:content Speed: 3, Position: (4, 5):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 2818276599 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2597904184: Position (4, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (4, 5)
# Anticipated position: (4, 6)
# Agent position: (4, 5)
# Anticipated position: (4, 7)
# Agent position: (4, 5)
# Anticipated position: []
# Agent position: (4, 5)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2597904184 position: (4, 5), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 6)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2597904184:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Agent position: (3, 4)
# Anticipated position: (3, 0)
# [Debug - Red Light Runner Check] Agent 2818276599 position: (3, 4), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2597904184: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2818276599 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 2090491037 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 1, Position: (2, 3):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 9461368620 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2818276599: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2818276599 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9461368620: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2818276599:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 2, Position: (2, 3):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 2090491037 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9461368620: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 1, Position: (4, 0):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 3)
# Anticipated position: (4, 3)
# Agent position: (3, 3)
# Anticipated position: (5, 3)
# Agent position: (3, 3)
# Anticipated position: (6, 3)
# Agent position: (3, 3)
# Anticipated position: (7, 3)
# [Debug - Red Light Runner Check] Agent 2090491037 position: (3, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9461368620: Position (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 3, Position: (5, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 1, Position: (4, 0):reply-with statusUpdate)
# Max cars reached
# Agent position: (5, 3)
# Anticipated position: (6, 3)
# Agent position: (5, 3)
# Anticipated position: (7, 3)
# Agent position: (5, 3)
# Anticipated position: []
# Agent position: (5, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2090491037 position: (5, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (6, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9461368620: Position (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2090491037:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 9461368620 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 2090491037: Position (7, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 2, Position: (4, 2):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 0, Position: (4, 1):reply-with statusUpdate)
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 9461368620 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 7), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 6)
# [Debug - Red Light Runner Check] Reading message from sender 9461368620: Position (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 3, Position: (3, 6):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 9461368620 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 3, Position: (4, 5):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 0, Position: (4, 1):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 0, Position: (3, 6):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 5)
# Anticipated position: (4, 6)
# Agent position: (4, 5)
# Anticipated position: (4, 7)
# Agent position: (4, 5)
# Anticipated position: []
# Agent position: (4, 5)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9461368620 position: (4, 5), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 6)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9461368620:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 1, Position: (4, 1):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 1, Position: (3, 5):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 9771393878 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 2, Position: (4, 2):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 6618752238:content Speed: 3, Position: (3, 6):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 9771393878 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 6618752238: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 2, Position: (4, 3):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Broadcasting status: (inform
# :sender 6618752238:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Agent position: (4, 3)
# Anticipated position: (4, 7)
# [Debug - Red Light Runner Check] Agent 9771393878 position: (4, 3), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6618752238: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Agent position: (3, 4)
# Anticipated position: (3, 0)
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 4), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Broadcasting status: (inform
# :sender 6618752238:content Speed: 3, Position: (3, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9771393878 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 6618752238: Position (3, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Broadcasting status: (inform
# :sender 6618752238:content Speed: 3, Position: (3, 2):reply-with statusUpdate)
# Max cars reached
# Agent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9771393878 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 2714741381: Position (3, 1)
# [Debug - Red Light Runner Check] Reading message from sender 6618752238: Position (3, 2)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9771393878:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2714741381 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 9771393878: Position (4, 7)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2714741381:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (3, 2)
# Anticipated position: (3, 1)
# Agent position: (3, 2)
# Anticipated position: (3, 0)
# Broadcasting status: (inform
# :sender 6618752238:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# [Debug - Red Light Runner Check] Agent 3295168172 position: (3, 7), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3295168172:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Agent position: (4, 0)
# Anticipated position: (4, 3)
# Agent position: (4, 0)
# Anticipated position: (4, 4)
# [Debug - Red Light Runner Check] Agent 8287082573 position: (4, 0), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 1)
# [Debug - Red Light Runner Check] Reading message from sender 3295168172: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8287082573:content Speed: 2, Position: (4, 1):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 3295168172 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 8287082573: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3295168172:content Speed: 3, Position: (3, 5):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Agent position: (4, 1)
# Anticipated position: (4, 5)
# [Debug - Red Light Runner Check] Agent 8287082573 position: (4, 1), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 3295168172: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8287082573:content Speed: 3, Position: (4, 2):reply-with statusUpdate)
# Agent position: (4, 0)
# Anticipated position: (4, 1)
# Agent position: (4, 0)
# Anticipated position: (4, 2)
# Broadcasting status: (inform
# :sender 4965043635:content Speed: 3, Position: (4, 1):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 3295168172 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 8287082573: Position (4, 2)
# [Debug - Red Light Runner Check] Reading message from sender 4965043635: Position (4, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3295168172:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (4, 2)
# Anticipated position: (4, 3)
# Agent position: (4, 2)
# Anticipated position: (4, 4)
# Agent position: (4, 2)
# Anticipated position: (4, 5)
# Agent position: (4, 2)
# Anticipated position: (4, 6)
# [Debug - Red Light Runner Check] Agent 8287082573 position: (4, 2), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3295168172: Position (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8287082573:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Agent position: (4, 1)
# Anticipated position: (4, 2)
# Agent position: (4, 1)
# Anticipated position: (4, 3)
# Agent position: (4, 1)
# Anticipated position: (4, 4)
# Broadcasting status: (inform
# :sender 4965043635:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3295168172 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 8287082573: Position (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 4965043635: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3295168172:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (4, 4)
# Anticipated position: (4, 5)
# Agent position: (4, 4)
# Anticipated position: (4, 6)
# Agent position: (4, 4)
# Anticipated position: (4, 7)
# Agent position: (4, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8287082573 position: (4, 4), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 5)
# [Debug - Red Light Runner Check] Reading message from sender 3295168172: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8287082573:content Speed: 3, Position: (4, 6):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (4, 4)
# Agent position: (4, 3)
# Anticipated position: (4, 5)
# Agent position: (4, 3)
# Anticipated position: (4, 6)
# Broadcasting status: (inform
# :sender 4965043635:content Speed: 3, Position: (4, 5):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3295168172 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 8287082573: Position (4, 6)
# [Debug - Red Light Runner Check] Reading message from sender 4965043635: Position (4, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3295168172:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (4, 6)
# Anticipated position: (4, 7)
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# Agent position: (4, 6)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 8287082573 position: (4, 6), Direction: 3
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 7)
# [Debug - Red Light Runner Check] Reading message from sender 3295168172: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 8287082573:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Agent position: (4, 5)
# Anticipated position: (4, 6)
# Agent position: (4, 5)
# Anticipated position: (4, 7)
# Broadcasting status: (inform
# :sender 4965043635:content Speed: 3, Position: (4, 7):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 7), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 3, Position: (3, 6):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 3, Position: (6, 4):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 0, Position: (3, 6):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 0, Position: (7, 4):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 1, Position: (7, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 0, Position: (3, 6):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 0, Position: (6, 4):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 0, Position: (7, 4):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 1, Position: (7, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 0, Position: (3, 6):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Agent position: (6, 4)
# Anticipated position: (3, 4)
# Agent position: (6, 4)
# Anticipated position: (2, 4)
# [Debug - Red Light Runner Check] Agent 5133023528 position: (6, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 6)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 1, Position: (5, 4):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 1, Position: (6, 4):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 6):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 2, Position: (5, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 2, Position: (6, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 5133023528: Position (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6243212282: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 5):reply-with statusUpdate)
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Agent position: (5, 4)
# Anticipated position: (2, 4)
# Agent position: (5, 4)
# Anticipated position: (1, 4)
# [Debug - Red Light Runner Check] Agent 5133023528 position: (5, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 2, Position: (4, 4):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 2, Position: (5, 4):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 2, Position: (3, 5):reply-with statusUpdate)
# Agent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Agent position: (4, 4)
# Anticipated position: (0, 4)
# [Debug - Red Light Runner Check] Agent 5133023528 position: (4, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 3, Position: (3, 4):reply-with statusUpdate)
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 3, Position: (4, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 5133023528: Position (3, 4)
# [Action - Red Light Runner Check] Agent 9453337000 detected a red light runner at (3, 4). Stopping.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 0, Position: (3, 5):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (2, 4)
# Agent position: (3, 4)
# Anticipated position: (1, 4)
# Agent position: (3, 4)
# Anticipated position: (0, 4)
# Agent position: (3, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5133023528 position: (3, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 3, Position: (1, 4):reply-with statusUpdate)
# Agent position: (4, 4)
# Anticipated position: (3, 4)
# Agent position: (4, 4)
# Anticipated position: (2, 4)
# Agent position: (4, 4)
# Anticipated position: (1, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 3, Position: (2, 4):reply-with statusUpdate)
# Max cars reached
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 5):reply-with statusUpdate)
# Agent position: (1, 4)
# Anticipated position: (0, 4)
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5133023528 position: (1, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (0, 4)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 5)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5133023528:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Agent position: (2, 4)
# Anticipated position: (1, 4)
# Agent position: (2, 4)
# Anticipated position: (0, 4)
# Broadcasting status: (inform
# :sender 6243212282:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 5133023528: Position (0, 4)
# [Debug - Red Light Runner Check] Reading message from sender 6243212282: Position (0, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 1, Position: (3, 4):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 2, Position: (3, 4):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Agent position: (3, 4)
# Anticipated position: (3, 0)
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 4), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 2, Position: (3, 3):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Agent position: (0, 3)
# Anticipated position: (3, 3)
# Agent position: (0, 3)
# Anticipated position: (4, 3)
# [Debug - Red Light Runner Check] Agent 1850233047 position: (0, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 1850233047:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Agent position: (7, 4)
# Anticipated position: (4, 4)
# Agent position: (7, 4)
# Anticipated position: (3, 4)
# [Debug - Red Light Runner Check] Agent 2263390517 position: (7, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (6, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2263390517:content Speed: 2, Position: (6, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2263390517: Position (6, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 3, Position: (3, 2):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 1850233047:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Agent position: (6, 4)
# Anticipated position: (5, 4)
# Agent position: (6, 4)
# Anticipated position: (4, 4)
# Agent position: (6, 4)
# Anticipated position: (3, 4)
# Agent position: (6, 4)
# Anticipated position: (2, 4)
# [Debug - Red Light Runner Check] Agent 2263390517 position: (6, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 2)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2263390517:content Speed: 3, Position: (5, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 2)
# Anticipated position: (3, 1)
# Agent position: (3, 2)
# Anticipated position: (3, 0)
# Agent position: (3, 2)
# Anticipated position: []
# Agent position: (3, 2)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 9453337000 position: (3, 2), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 1)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 2263390517: Position (5, 4)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 9453337000:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 1850233047:content Speed: 1, Position: (1, 3):reply-with statusUpdate)
# Agent position: (5, 4)
# Anticipated position: (4, 4)
# Agent position: (5, 4)
# Anticipated position: (3, 4)
# Agent position: (5, 4)
# Anticipated position: (2, 4)
# Agent position: (5, 4)
# Anticipated position: (1, 4)
# [Debug - Red Light Runner Check] Agent 2263390517 position: (5, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (4, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] Reading message from sender 9453337000: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2263390517:content Speed: 3, Position: (3, 4):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 4)
# Anticipated position: (2, 4)
# Agent position: (3, 4)
# Anticipated position: (1, 4)
# Agent position: (3, 4)
# Anticipated position: (0, 4)
# Agent position: (3, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2263390517 position: (3, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2263390517:content Speed: 3, Position: (1, 4):reply-with statusUpdate)
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 1850233047:content Speed: 0, Position: (1, 3):reply-with statusUpdate)
# Agent position: (1, 4)
# Anticipated position: (0, 4)
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# Agent position: (1, 4)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 2263390517 position: (1, 4), Direction: 2
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (0, 4)
# [Debug - Red Light Runner Check] Reading message from sender 1850233047: Position (1, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2263390517:content Speed: 3, Position: (0, 4):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Agent position: (7, 4)
# Anticipated position: (4, 4)
# Agent position: (7, 4)
# Anticipated position: (3, 4)
# ...
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 2740667495:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Broadcasting status: (inform
# :sender 4101843518:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (3, 4)
# Anticipated position: (3, 3)
# Agent position: (3, 4)
# Anticipated position: (3, 2)
# Agent position: (3, 4)
# Anticipated position: (3, 1)
# Broadcasting status: (inform
# :sender 4076990647:content Speed: 3, Position: (3, 2):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 2)
# Anticipated position: (3, 1)
# Broadcasting status: (inform
# :sender 4076990647:content Speed: 1, Position: (3, 2):reply-with statusUpdate)
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 4101843518 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 4101843518:content Speed: 3, Position: (3, 0):reply-with statusUpdate)
# Agent position: (3, 2)
# Anticipated position: (3, 1)
# Agent position: (3, 2)
# Anticipated position: (3, 0)
# Broadcasting status: (inform
# :sender 4076990647:content Speed: 1, Position: (3, 1):reply-with statusUpdate)
# Agent position: (0, 3)
# Anticipated position: (1, 3)
# Agent position: (0, 3)
# Anticipated position: (2, 3)
# Broadcasting status: (inform
# :sender 5201664390:content Speed: 2, Position: (1, 3):reply-with statusUpdate)
# Max cars reached
# Agent position: (1, 3)
# Anticipated position: (2, 3)
# Agent position: (1, 3)
# Anticipated position: (3, 3)
# Agent position: (1, 3)
# Anticipated position: (4, 3)
# Agent position: (1, 3)
# Anticipated position: (5, 3)
# [Debug - Red Light Runner Check] Agent 5201664390 position: (1, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (2, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4076990647: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5201664390:content Speed: 3, Position: (2, 3):reply-with statusUpdate)
# Broadcasting status: (inform
# :sender 4076990647:content Speed: 1, Position: (3, 1):reply-with statusUpdate)
# Agent position: (2, 3)
# Anticipated position: (3, 3)
# Agent position: (2, 3)
# Anticipated position: (4, 3)
# Agent position: (2, 3)
# Anticipated position: (5, 3)
# Agent position: (2, 3)
# Anticipated position: (6, 3)
# [Debug - Red Light Runner Check] Agent 5201664390 position: (2, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 3)
# [Debug - Red Light Runner Check] Reading message from sender 4076990647: Position (3, 1)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5201664390:content Speed: 3, Position: (4, 3):reply-with statusUpdate)
# Agent position: (3, 7)
# Anticipated position: (3, 6)
# Agent position: (3, 7)
# Anticipated position: (3, 5)
# Agent position: (3, 7)
# Anticipated position: (3, 4)
# Agent position: (3, 7)
# Anticipated position: (3, 3)
# [Debug - Red Light Runner Check] Agent 3268913991 position: (3, 7), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 6)
# [Debug - Red Light Runner Check] Reading message from sender 5201664390: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3268913991:content Speed: 2, Position: (3, 6):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 1)
# Anticipated position: (3, 0)
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# Agent position: (3, 1)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 4076990647 position: (3, 1), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 0)
# [Debug - Red Light Runner Check] Reading message from sender 5201664390: Position (4, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 4076990647:content Speed: 2, Position: (3, 0):reply-with statusUpdate)
# Agent position: (4, 3)
# Anticipated position: (5, 3)
# Agent position: (4, 3)
# Anticipated position: (6, 3)
# Agent position: (4, 3)
# Anticipated position: (7, 3)
# Agent position: (4, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5201664390 position: (4, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (5, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3268913991: Position (3, 6)
# [Debug - Red Light Runner Check] Reading message from sender 4076990647: Position (3, 0)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5201664390:content Speed: 3, Position: (6, 3):reply-with statusUpdate)
# Agent position: (3, 6)
# Anticipated position: (3, 5)
# Agent position: (3, 6)
# Anticipated position: (3, 4)
# Agent position: (3, 6)
# Anticipated position: (3, 3)
# Agent position: (3, 6)
# Anticipated position: (3, 2)
# [Debug - Red Light Runner Check] Agent 3268913991 position: (3, 6), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 5)
# [Debug - Red Light Runner Check] Reading message from sender 5201664390: Position (6, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3268913991:content Speed: 3, Position: (3, 5):reply-with statusUpdate)
# Max cars reached
# Agent position: (3, 5)
# Anticipated position: (3, 4)
# Agent position: (3, 5)
# Anticipated position: (3, 3)
# Agent position: (3, 5)
# Anticipated position: (3, 2)
# Agent position: (3, 5)
# Anticipated position: (3, 1)
# [Debug - Red Light Runner Check] Agent 3268913991 position: (3, 5), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 4)
# [Debug - Red Light Runner Check] Reading message from sender 5201664390: Position (6, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3268913991:content Speed: 3, Position: (3, 3):reply-with statusUpdate)
# Agent position: (6, 3)
# Anticipated position: (7, 3)
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# Agent position: (6, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 5201664390 position: (6, 3), Direction: 1
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (7, 3)
# [Debug - Red Light Runner Check] Reading message from sender 3268913991: Position (3, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 5201664390:content Speed: 3, Position: (7, 3):reply-with statusUpdate)
# Agent position: (3, 3)
# Anticipated position: (3, 2)
# Agent position: (3, 3)
# Anticipated position: (3, 1)
# Agent position: (3, 3)
# Anticipated position: (3, 0)
# Agent position: (3, 3)
# Anticipated position: []
# [Debug - Red Light Runner Check] Agent 3268913991 position: (3, 3), Direction: 4
# [Debug - Red Light Runner Check] Anticipated position for distance 1: (3, 2)
# [Debug - Red Light Runner Check] Reading message from sender 5201664390: Position (7, 3)
# [Debug - Red Light Runner Check] No red light runners detected.
# Broadcasting status: (inform
# :sender 3268913991:content Speed: 3, Position: (3, 1):reply-with statusUpdate)
# Agent position: (7, 4)
# Anticipated position: (6, 4)
# Agent position: (7, 4)
# Anticipated position: (5, 4)
# Broadcasting status: (inform
# :sender 9292985665:content Speed: 3, Position: (6, 4):reply-with statusUpdate)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img932e71476a444abe95ae8a50f96dbcf4">
#   <div class="anim-controls">
#     <input id="_anim_slider932e71476a444abe95ae8a50f96dbcf4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim932e71476a444abe95ae8a50f96dbcf4.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim932e71476a444abe95ae8a50f96dbcf4.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim932e71476a444abe95ae8a50f96dbcf4.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim932e71476a444abe95ae8a50f96dbcf4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim932e71476a444abe95ae8a50f96dbcf4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim932e71476a444abe95ae8a50f96dbcf4.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim932e71476a444abe95ae8a50f96dbcf4.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim932e71476a444abe95ae8a50f96dbcf4.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim932e71476a444abe95ae8a50f96dbcf4.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim932e71476a444abe95ae8a50f96dbcf4.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select932e71476a444abe95ae8a50f96dbcf4"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_932e71476a444abe95ae8a50f96dbcf4"
#              >
#       <label for="_anim_radio1_932e71476a444abe95ae8a50f96dbcf4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_932e71476a444abe95ae8a50f96dbcf4"
#              checked>
#       <label for="_anim_radio2_932e71476a444abe95ae8a50f96dbcf4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_932e71476a444abe95ae8a50f96dbcf4"
#              >
#       <label for="_anim_radio3_932e71476a444abe95ae8a50f96dbcf4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img932e71476a444abe95ae8a50f96dbcf4";
#     var slider_id = "_anim_slider932e71476a444abe95ae8a50f96dbcf4";
#     var loop_select_id = "_anim_loop_select932e71476a444abe95ae8a50f96dbcf4";
#     var frames = new Array(151);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/H5lhTAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAuoUlE

# %%
class Car:
    def __init__(self, speed=0):
        self.id = 1  # Unique identifier for each car
        self.speed = speed
        # Add more initialization stuff here as needed
    
    def broadcast_speed(self):
        # Assuming 'self.id' is a unique identifier for each car
        speed_message = Message(
            performative="inform",
            content=str(self.speed),
            sender=str(self.id),
            query="speedUpdate",
            is_reply=False
        )
        # Now, you'd broadcast this message to the network, system, or however your cars communicate
        # This part depends on your setup - maybe you add it to a global messaging system, or each car has a list of others it can "hear"
        print(speed_message)


#test car
car = Car(3)
car.broadcast_speed()
# Out:
# (inform
# :sender 1:content 3:reply-with speedUpdate)
